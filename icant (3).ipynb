# %%
import os
import numpy as np
import tensorflow as tf
import keras
from keras import layers
import nibabel as nib
from scipy import ndimage
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve
from sklearn.utils.class_weight import compute_class_weight

# Define paths to your dataset
data_dir = "/kaggle/input/all-zendo-dataset/DATA"
t2wi_dir = os.path.join(data_dir, "T2WI")
csv_path = "/kaggle/input/all-zendo-dataset/DATA/all_centers_combined.csv"

# Load the CSV file
df = pd.read_csv(csv_path)
df['image_name'] = df['image_name'].str.replace('.nii.gz', '.nii')

# Helper functions for preprocessing
def read_nifti_file(filepath):
    scan = nib.load(filepath).get_fdata()
    return scan

def normalize(volume):
    min_hu, max_hu = -1000, 400
    volume = np.clip(volume, min_hu, max_hu)
    volume = (volume - min_hu) / (max_hu - min_hu)
    return volume.astype("float32")

def resize_volume(img):
    desired_depth, desired_width, desired_height = 64, 128, 128
    current_depth, current_width, current_height = img.shape[-1], img.shape[0], img.shape[1]
    depth_factor = current_depth / desired_depth
    width_factor = current_width / desired_width
    height_factor = current_height / desired_height
    img = ndimage.rotate(img, 90, reshape=False)
    img = ndimage.zoom(img,
                       (1/width_factor, 1/height_factor, 1/depth_factor),
                       order=1)
    return img

def process_scan(path):
    volume = read_nifti_file(path)
    volume = normalize(volume)
    return resize_volume(volume)

# Load and pair T2WI images with labels
nmbic_scan_paths = []
mbic_scan_paths = []
for subfolder in os.listdir(t2wi_dir):
    folder = os.path.join(t2wi_dir, subfolder)
    if not os.path.isdir(folder):
        continue
    files = [f for f in os.listdir(folder) if f.endswith(".nii")]
    if not files:
        continue
    path = os.path.join(folder, files[0])
    img_id = subfolder.split(".")[0]
    row = df[df['image_name'].str.replace('.nii', '') == img_id]
    if row.empty:
        print(f"No label found for T2WI ID {img_id}")
        continue
    label = int(row['label'].iloc[0])
    if label == 0:
        nmbic_scan_paths.append(path)
    else:
        mbic_scan_paths.append(path)

print(f"NMBIC scans: {len(nmbic_scan_paths)}")
print(f"MBIC scans: {len(mbic_scan_paths)}")

# Process scans
nmbic_scans = np.array([process_scan(p) for p in nmbic_scan_paths])
mbic_scans = np.array([process_scan(p) for p in mbic_scan_paths])

# Assign labels
nmbic_labels = np.zeros(len(nmbic_scans), dtype=int)
mbic_labels = np.ones(len(mbic_scans), dtype=int)

# Split data into training, validation, and test (60-20-20)
def split_data(X, y, train_ratio=0.6, val_ratio=0.2):
    n_total = len(X)
    n_train = int(train_ratio * n_total)
    n_val = int(val_ratio * n_total)
    return X[:n_train], y[:n_train], X[n_train:n_train+n_val], y[n_train:n_train+n_val], X[n_train+n_val:], y[n_train+n_val:]

x_tr_n, y_tr_n, x_val_n, y_val_n, x_test_n, y_test_n = split_data(nmbic_scans, nmbic_labels)
x_tr_p, y_tr_p, x_val_p, y_val_p, x_test_p, y_test_p = split_data(mbic_scans, mbic_labels)

x_train = np.concatenate((x_tr_p, x_tr_n), axis=0)
y_train = np.concatenate((y_tr_p, y_tr_n), axis=0)
x_val = np.concatenate((x_val_p, x_val_n), axis=0)
y_val = np.concatenate((y_val_p, y_val_n), axis=0)
x_test = np.concatenate((x_test_p, x_test_n), axis=0)
y_test = np.concatenate((y_test_p, y_test_n), axis=0)

print(f"Number of samples in train, validation, and test are {x_train.shape[0]}, {x_val.shape[0]}, and {x_test.shape[0]}.")

# Address class imbalance via class weights
classes = np.unique(y_train)
cw = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weight_dict = dict(zip(classes, cw))
print("Computed class weights:", class_weight_dict)

# Data augmentation
def rotate(volume):
    def scipy_rotate(vol):
        angles = [-20, -10, -5, 5, 10, 20]
        angle = np.random.choice(angles)
        vol = ndimage.rotate(vol, angle, reshape=False)
        vol = np.clip(vol, 0, 1)
        return vol
    return tf.numpy_function(scipy_rotate, [volume], tf.float32)

def train_preprocessing(volume, label):
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

def validation_preprocessing(volume, label):
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

# Define data loaders
batch_size = 4

# Evaluate on the validation set
metrics = model.evaluate(validation_dataset, verbose=0)
val_loss, val_accuracy, val_precision, val_recall, val_auc = metrics
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(f"Validation Precision: {val_precision:.4f}")
print(f"Validation Recall: {val_recall:.4f}")
print(f"Validation AUC: {val_auc:.4f}")

# Evaluate on the test set
metrics = model.evaluate(test_dataset, verbose=0)
test_loss, test_accuracy, test_precision, test_recall, test_auc = metrics
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test AUC: {test_auc:.4f}")

# Plot training and validation metrics
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()

plt.subplot(2, 2, 3)
plt.plot(history.history['recall'], label='Training Recall')
plt.plot(history.history['val_recall'], label='Validation Recall')
plt.title('Recall'); plt.xlabel('Epoch'); plt.ylabel('Recall'); plt.legend()

plt.subplot(2, 2, 4)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.title('AUC'); plt.xlabel('Epoch'); plt.ylabel('AUC'); plt.legend()

plt.tight_layout()
plt.savefig('metrics.png')
plt.show()

# Collect true labels and predictions for validation set
y_val_list = np.array([y.numpy() for _, y in validation_dataset.unbatch()]).astype(int)
y_val_pred = model.predict(validation_dataset)
y_val_pred_binary = (y_val_pred > 0.5).astype(int)

# DataFrame of validation predictions
val_df = pd.DataFrame({
    'Sample Index': np.arange(len(y_val_list)),
    'True Label': ['MBIC' if l==1 else 'NMBIC' for l in y_val_list],
    'Pred Label': ['MBIC' if p==1 else 'NMBIC' for p in y_val_pred_binary.flatten()],
    'Pred Prob': y_val_pred.flatten()
})
print(val_df)
val_df.to_csv('validation_predictions.csv', index=False)

# Classification report & confusion matrix for validation set
print("Validation Classification Report:")
print(classification_report(y_val_list, y_val_pred_binary, target_names=["NMBIC","MBIC"]))
cm = confusion_matrix(y_val_list, y_val_pred_binary)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['NMBIC','MBIC'], yticklabels=['NMBIC','MBIC'])
plt.title('Validation Confusion Matrix (threshold=0.5)')
plt.xlabel('Predicted'); plt.ylabel('Actual')
plt.show()

# Threshold optimization for validation set
precisions, recalls, thresholds = precision_recall_curve(y_val_list, y_val_pred)
opt_thr_f1 = thresholds[np.argmax(2*(precisions*recalls)/(precisions+recalls+1e-8))]
print(f"Validation Optimal threshold (max F1): {opt_thr_f1:.2f}")
y_val_pred_opt = (y_val_pred > opt_thr_f1).astype(int)
print("Validation Classification Report (Optimal Threshold):")
print(classification_report(y_val_list, y_val_pred_opt, target_names=["NMBIC","MBIC"]))
cm_opt = confusion_matrix(y_val_list, y_val_pred_opt)
sns.heatmap(cm_opt, annot=True, fmt='d', cmap='Blues',
            xticklabels=['NMBIC','MBIC'], yticklabels=['NMBIC','MBIC'])
plt.title(f'Validation Confusion Matrix (threshold={opt_thr_f1:.2f})')
plt.xlabel('Predicted'); plt.ylabel('Actual')
plt.show()

# Collect true labels and predictions for test set
y_test_list = np.array([y.numpy() for _, y in test_dataset.unbatch()]).astype(int)
y_test_pred = model.predict(test_dataset)
y_test_pred_binary = (y_test_pred > 0.5).astype(int)

# DataFrame of test predictions
test_df = pd.DataFrame({
    'Sample Index': np.arange(len(y_test_list)),
    'True Label': ['MBIC' if l==1 else 'NMBIC' for l in y_test_list],
    'Pred Label': ['MBIC' if p==1 else 'NMBIC' for p in y_test_pred_binary.flatten()],
    'Pred Prob': y_test_pred.flatten()
})
print(test_df)
test_df.to_csv('test_predictions.csv', index=False)

# Classification report & confusion matrix for test set
print("Test Classification Report:")
print(classification_report(y_test_list, y_test_pred_binary, target_names=["NMBIC","MBIC"]))
cm = confusion_matrix(y_test_list, y_test_pred_binary)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['NMBIC','MBIC'], yticklabels=['NMBIC','MBIC'])
plt.title('Test Confusion Matrix (threshold=0.5)')
plt.xlabel('Predicted'); plt.ylabel('Actual')
plt.show()

# Threshold optimization for test set
precisions, recalls, thresholds = precision_recall_curve(y_test_list, y_test_pred)
opt_thr_f1 = thresholds[np.argmax(2*(precisions*recalls)/(precisions+recalls+1e-8))]
print(f"Test Optimal threshold (max F1): {opt_thr_f1:.2f}")
y_test_pred_opt = (y_test_pred > opt_thr_f1).astype(int)
print("Test Classification Report (Optimal Threshold):")
print(classification_report(y_test_list, y_test_pred_opt, target_names=["NMBIC","MBIC"]))
cm_opt = confusion_matrix(y_test_list, y_test_pred_opt)
sns.heatmap(cm_opt, annot=True, fmt='d', cmap='Blues',
            xticklabels=['NMBIC','MBIC'], yticklabels=['NMBIC','MBIC'])
plt.title(f'Test Confusion Matrix (threshold={opt_thr_f1:.2f})')
plt.xlabel('Predicted'); plt.ylabel('Actual')
plt.show()

# Save the model
model.save('cnn_bladder_massive.keras')
print("Model saved as 'cnn_bladder_massive.keras'")
train_dataset = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(len(x_train))
    .map(train_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(2)
)
validation_dataset = (
    tf.data.Dataset.from_tensor_slices((x_val, y_val))
    .map(validation_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(2)
)
test_dataset = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .map(validation_preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(2)
)

# Define 3D CNN model
def get_model(width=128, height=128, depth=64):
    inputs = keras.Input((width, height, depth, 1))
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(units=1, activation="sigmoid")(x)
    return keras.Model(inputs, outputs, name="3dcnn")

# Build and compile model
model = get_model(width=128, height=128, depth=64)
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=[
        "accuracy",
        keras.metrics.Precision(name="precision"),
        keras.metrics.Recall(name="recall"),
        keras.metrics.AUC(name="auc")
    ],
    run_eagerly=True,
)
model.summary()

# Define callbacks
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "3d_bladder_classification.keras", save_best_only=True
)
early_stopping_cb = keras.callbacks.EarlyStopping(
    monitor="val_recall",
    mode="max",
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# Train the model with class weights
epochs = 100
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    class_weight=class_weight_dict,
    verbose=2,
    callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# 2025-05-04 22:06:11.668529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746396371.853881      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746396371.910749      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# NMBIC scans: 140
# MBIC scans: 80
# Number of samples in train, validation, and test are 132, 44, and 44.
# Computed class weights: {0: 0.7857142857142857, 1: 1.375}
# I0000 00:00:1746396578.169612      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "3dcnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 64, 1)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d (Conv3D)                      │ (None, 126, 126, 62, 64)    │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 63, 63, 31, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 63, 63, 31, 64)      │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_1 (Conv3D)                    │ (None, 61, 61, 29, 64)      │         110,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 30, 30, 14, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 30, 30, 14, 64)      │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_2 (Conv3D)                    │ (None, 28, 28, 12, 128)     │         221,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 14, 14, 6, 128)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 14, 14, 6, 128)      │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_3 (Conv3D)                    │ (None, 12, 12, 4, 256)      │         884,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_3 (MaxPooling3D)       │ (None, 6, 6, 2, 256)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 6, 2, 256)        │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling3d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling3D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,352,897 (5.16 MB)
#  Trainable params: 1,351,873 (5.16 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/100
# I0000 00:00:1746396582.921476      31 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 33/33 - 22s - 659ms/step - accuracy: 0.5076 - auc: 0.4781 - loss: 0.8380 - precision: 0.3559 - recall: 0.4375 - val_accuracy: 0.3636 - val_auc: 0.4330 - val_loss: 0.6954 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 2/100
# 33/33 - 15s - 461ms/step - accuracy: 0.5530 - auc: 0.5370 - loss: 0.7684 - precision: 0.4154 - recall: 0.5625 - val_accuracy: 0.3636 - val_auc: 0.4375 - val_loss: 0.7190 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 3/100
# 33/33 - 15s - 453ms/step - accuracy: 0.5303 - auc: 0.5707 - loss: 0.7037 - precision: 0.4205 - recall: 0.7708 - val_accuracy: 0.6364 - val_auc: 0.5000 - val_loss: 0.6872 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 33/33 - 15s - 458ms/step - accuracy: 0.5000 - auc: 0.5355 - loss: 0.7188 - precision: 0.3750 - recall: 0.5625 - val_accuracy: 0.3636 - val_auc: 0.4464 - val_loss: 0.7128 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 5/100
# 33/33 - 15s - 453ms/step - accuracy: 0.5379 - auc: 0.5833 - loss: 0.6822 - precision: 0.3968 - recall: 0.5208 - val_accuracy: 0.6364 - val_auc: 0.5692 - val_loss: 0.6603 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 33/33 - 15s - 453ms/step - accuracy: 0.5227 - auc: 0.5496 - loss: 0.7331 - precision: 0.3973 - recall: 0.6042 - val_accuracy: 0.3636 - val_auc: 0.4643 - val_loss: 0.7457 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 7/100
# 33/33 - 15s - 449ms/step - accuracy: 0.6439 - auc: 0.6467 - loss: 0.6730 - precision: 0.5106 - recall: 0.5000 - val_accuracy: 0.3636 - val_auc: 0.4386 - val_loss: 0.8479 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 8/100
# 33/33 - 15s - 453ms/step - accuracy: 0.6439 - auc: 0.6066 - loss: 0.7063 - precision: 0.5102 - recall: 0.5208 - val_accuracy: 0.6364 - val_auc: 0.4297 - val_loss: 0.6841 - val_precision: 0.5000 - val_recall: 0.3125
# Epoch 9/100
# 33/33 - 15s - 454ms/step - accuracy: 0.5455 - auc: 0.6416 - loss: 0.6966 - precision: 0.4268 - recall: 0.7292 - val_accuracy: 0.3636 - val_auc: 0.4241 - val_loss: 0.8786 - val_precision: 0.3636 - val_recall: 1.0000
# Epoch 10/100
# 33/33 - 15s - 451ms/step - accuracy: 0.6212 - auc: 0.6979 - loss: 0.6367 - precision: 0.4839 - recall: 0.6250 - val_accuracy: 0.3864 - val_auc: 0.7333 - val_loss: 0.6944 - val_precision: 0.3721 - val_recall: 1.0000
# Epoch 11/100

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import cv2
from scipy.ndimage import zoom
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import imgaug.augmenters as iaa
from tqdm import tqdm
import uuid

# Define paths to your dataset
data_dir = "/kaggle/input/all-zendo-dataset/DATA"
t2wi_dir = os.path.join(data_dir, "T2WI")
csv_path = "/kaggle/input/all-zendo-dataset/DATA/all_centers_combined.csv"

# Load the CSV file
df = pd.read_csv(csv_path)
df['image_name'] = df['image_name'].str.replace('.nii.gz', '.nii')
df['mask_name'] = df['mask_name'].str.replace('.nii.gz', '.nii')

# NEW: Print DataFrame info to verify contents
print(f"Loaded DataFrame with {len(df)} rows")
print("Sample image names:", df['image_name'].head().tolist())
print("Columns in DataFrame:", df.columns.tolist())

# Helper functions for preprocessing (inspired by preprocessing_for_classification.py)
def read_nifti_file(filepath):
    try:
        scan = nib.load(filepath).get_fdata()
        return scan
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return None

def linear_normalizing(data):
    """Normalize image intensities to [0, 1]."""
    data_min = np.min(data)
    data_max = np.max(data)
    return (data - data_min) / (data_max - data_min + 1e-6)

def centre_window_cropping(data, reshapesize=(128, 128)):
    """Crop or pad to target size around the center."""
    or_size = data.shape
    target_size = (reshapesize[0], reshapesize[1], or_size[2])
    
    # Pad if original size is smaller than target
    if target_size[0] > or_size[0]:
        pad_size = (target_size[0] - or_size[0]) // 2
        data = np.pad(data, ((pad_size, pad_size), (0, 0), (0, 0)), mode='constant')
    if target_size[1] > or_size[1]:
        pad_size = (target_size[1] - or_size[1]) // 2
        data = np.pad(data, ((0, 0), (pad_size, pad_size), (0, 0)), mode='constant')
    
    # Center crop
    cur_size = data.shape
    centre_x = cur_size[0] // 2
    centre_y = cur_size[1] // 2
    dx = target_size[0] // 2
    dy = target_size[1] // 2
    data = data[centre_x - dx:centre_x + dx, centre_y - dy:centre_y + dy, :]
    
    # Resize each slice
    data_resize = np.zeros((reshapesize[0], reshapesize[1], cur_size[2]))
    for kk in range(cur_size[2]):
        data_resize[:, :, kk] = cv2.resize(data[:, :, kk], reshapesize, interpolation=cv2.INTER_NEAREST)
    
    return data_resize

def block_dividing(data, deep=1, step=1):
    """Divide 3D volume into 2D slices."""
    data_group = []
    o_data_deep = data.shape[2]
    
    # NEW: Log the depth of the volume
    print(f"Block dividing: Volume depth = {o_data_deep}")
    
    if o_data_deep <= deep:
        tmp_data = np.zeros((data.shape[0], data.shape[1], deep))
        tmp_data[:, :, :o_data_deep] = data
        data_group.append(tmp_data[:, :, 0])
    else:
        blocks = (o_data_deep - deep) // step + 2
        if (o_data_deep - deep) % step == 0:
            blocks -= 1
        for i in range(blocks - 1):
            tmp_data = data[:, :, i * step:i * step + deep]
            data_group.append(tmp_data[:, :, 0])
        tmp_data = data[:, :, o_data_deep - deep:o_data_deep]
        data_group.append(tmp_data[:, :, 0])
    
    # NEW: Log the number of slices generated
    print(f"Generated {len(data_group)} slices")
    return data_group

def preprocess_image(image_path, mask_path, reshapesize=(128, 128)):
    """Preprocess a single image and mask pair."""
    # NEW: Check if files exist
    if not os.path.exists(image_path):
        print(f"Image not found: {image_path}")
        return [], []
    if not os.path.exists(mask_path):
        print(f"Mask not found: {mask_path}")
        return [], []
    
    # Load NIfTI files
    image = read_nifti_file(image_path)
    mask = read_nifti_file(mask_path)
    
    if image is None or mask is None:
        print(f"Skipping {image_path} due to loading error")
        return [], []
    
    # NEW: Check if volumes are empty
    if image.size == 0 or mask.size == 0:
        print(f"Empty volume for {image_path}")
        return [], []
    
    # Binarize mask
    mask[mask < 0.5] = 0
    mask[mask >= 0.5] = 1
    
    # Crop and resize
    image = centre_window_cropping(image, reshapesize)
    mask = centre_window_cropping(mask, reshapesize)
    
    # Normalize image
    image = linear_normalizing(image)
    
    # Divide into 2D slices
    image_slices = block_dividing(image)
    mask_slices = block_dividing(mask)
    
    # NEW: Verify that slices are generated
    if len(image_slices) == 0 or len(mask_slices) == 0:
        print(f"No slices generated for {image_path}")
        return [], []
    
    return image_slices, mask_slices

# Custom Dataset (inspired by Data_loader.py)
class SegmentationDataset(Dataset):
    def __init__(self, df, t2wi_dir, augmentation=False, reshapesize=(128, 128)):
        self.df = df
        self.t2wi_dir = t2wi_dir
        self.augmentation = augmentation
        self.reshapesize = reshapesize
        self.image_slices = []
        self.mask_slices = []
        
        # NEW: Check if DataFrame is empty
        if len(df) == 0:
            print("Warning: Input DataFrame is empty")
            return
        
        # Preprocess all images and masks
        valid_pairs = 0
        for idx, row in df.iterrows():
            image_path = os.path.join(t2wi_dir, row['image_name'])
            print("right HERE",image_path)
            mask_path = os.path.join(t2wi_dir, row['image_name'].replace('.nii', '_mask.nii'))
            print(f"Processing {image_path}")  # NEW: Log processing
            img_slices, msk_slices = preprocess_image(image_path, mask_path, reshapesize)
            if img_slices and msk_slices:
                self.image_slices.extend(img_slices)
                self.mask_slices.extend(msk_slices)
                valid_pairs += 1
            else:
                print(f"Skipped {image_path} due to invalid slices")
        
        # NEW: Log the number of valid pairs and slices
        print(f"Found {valid_pairs} valid image-mask pairs")
        print(f"Total slices: {len(self.image_slices)}")
    
    def __len__(self):
        # NEW: Raise error if dataset is empty
        if len(self.image_slices) == 0:
            raise ValueError("Dataset is empty. No valid image-mask pairs found.")
        return len(self.image_slices)
    
    def __getitem__(self, idx):
        image = self.image_slices[idx]
        mask = self.mask_slices[idx]
        
        # Convert to 3-channel image (RGB-like)
        image = np.stack([image, image, image], axis=0)  # Shape: (3, H, W)
        mask = mask[np.newaxis, :, :]  # Shape: (1, H, W)
        
        if self.augmentation:
            # Prepare for augmentation
            image = np.transpose(image, (1, 2, 0))  # Shape: (H, W, 3)
            mask = mask[0, :, :]  # Shape: (H, W)
            # Apply augmentation
            aug_det = self.seq.to_deterministic()
            image = aug_det.augment_image(image)
            mask = aug_det.augment_image(mask)
            # Convert back
            image = np.transpose(image, (2, 0, 1))  # Shape: (3, H, W)
            mask = mask[np.newaxis, :, :]  # Shape: (1, H, W)
        
        return torch.FloatTensor(image), torch.FloatTensor(mask)

# U-Net Model
class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1):
        super(UNet, self).__init__()
        
        def conv_block(in_ch, out_ch):
            return nn.Sequential(
                nn.Conv2d(in_ch, out_ch, 3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_ch, out_ch, 3, padding=1),
                nn.ReLU(inplace=True)
            )
        
        self.enc1 = conv_block(in_channels, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)
        
        self.pool = nn.MaxPool2d(2)
        
        self.bottleneck = conv_block(512, 1024)
        
        self.upconv4 = nn.ConvTranspose2d(1024, 512, 2, stride=2)
        self.dec4 = conv_block(1024, 512)
        self.upconv3 = nn.ConvTranspose2d(512, 256, 2, stride=2)
        self.dec3 = conv_block(512, 256)
        self.upconv2 = nn.ConvTranspose2d(256, 128, 2, stride=2)
        self.dec2 = conv_block(256, 128)
        self.upconv1 = nn.ConvTranspose2d(128, 64, 2, stride=2)
        self.dec1 = conv_block(128, 64)
        
        self.final = nn.Conv2d(64, out_channels, 1)
    
    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        
        # Bottleneck
        b = self.bottleneck(self.pool(e4))
        
        # Decoder
        d4 = self.upconv4(b)
        d4 = torch.cat([d4, e4], dim=1)
        d4 = self.dec4(d4)
        
        d3 = self.upconv3(d4)
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)
        
        d2 = self.upconv2(d3)
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)
        
        d1 = self.upconv1(d2)
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)
        
        return torch.sigmoid(self.final(d1))

# Metrics
def dice_score(pred, target, smooth=1e-6):
    pred = (pred > 0.5).float()
    intersection = (pred * target).sum()
    return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

def iou_score(pred, target, smooth=1e-6):
    pred = (pred > 0.5).float()
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + smooth) / (union + smooth)

# Training and Evaluation
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    train_losses = []
    val_dices = []
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for images, masks in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            images, masks = images.to(device), masks.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, masks)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * images.size(0)
        
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        # Validation
        model.eval()
        val_dice = 0.0
        val_iou = 0.0
        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(device), masks.to(device)
                outputs = model(images)
                val_dice += dice_score(outputs, masks).item() * images.size(0)
                val_iou += iou_score(outputs, masks).item() * images.size(0)
        
        val_dice /= len(val_loader.dataset)
        val_iou /= len(val_loader.dataset)
        val_dices.append(val_dice)
        
        print(f"Epoch {epoch+1}/{num_epochs} - Loss: {train_loss:.4f}, Val Dice: {val_dice:.4f}, Val IoU: {val_iou:.4f}")
    
    return train_losses, val_dices

# Visualize predictions
def visualize_predictions(model, loader, device, num_samples=3):
    model.eval()
    with torch.no_grad():
        for images, masks in loader:
            images, masks = images.to(device), masks.to(device)
            preds = model(images)
            preds = (preds > 0.5).float()
            
            for i in range(min(num_samples, images.size(0))):
                plt.figure(figsize=(12, 4))
                
                plt.subplot(1, 3, 1)
                plt.title("Input Image")
                plt.imshow(images[i, 0, :, :].cpu().numpy(), cmap='gray')
                plt.axis('off')
                
                plt.subplot(1, 3, 2)
                plt.title("Ground Truth")
                plt.imshow(masks[i, 0, :, :].cpu().numpy(), cmap='gray')
                plt.axis('off')
                
                plt.subplot(1, 3, 3)
                plt.title("Prediction")
                plt.imshow(preds[i, 0, :, :].cpu().numpy(), cmap='gray')
                plt.axis('off')
                
                plt.show()
            
            break

# Main execution
if __name__ == "__main__":
    # Device configuration
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Split dataset
    train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
    
    # NEW: Print DataFrame splits
    print(f"Training set: {len(train_df)} samples")
    print(f"Validation set: {len(val_df)} samples")
    
    # Create datasets and loaders
    train_dataset = SegmentationDataset(train_df, t2wi_dir, augmentation=True)
    val_dataset = SegmentationDataset(val_df, t2wi_dir, augmentation=False)
    
    # NEW: Check dataset sizes before creating loaders
    print(f"Train dataset size: {len(train_dataset)} slices")
    print(f"Validation dataset size: {len(val_dataset)} slices")
    
    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)
    
    # Initialize model, loss, and optimizer
    model = UNet(in_channels=3, out_channels=1).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    # Train model
    num_epochs = 20
    train_losses, val_dices = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
    
    # Save model
    torch.save(model.state_dict(), "/kaggle/working/unet_segmentation.pth")
    
    # Visualize predictions
    visualize_predictions(model, val_loader, device)
    
    # Plot training metrics
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label="Training Loss")
    plt.title("Training Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(val_dices, label="Validation Dice")
    plt.title("Validation Dice Score")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    
    plt.tight_layout()
    plt.savefig("/kaggle/working/training_metrics.png")
    plt.show()
# Out:
# Loaded DataFrame with 274 rows
# Sample image names: ['c1_001.nii', 'c1_002.nii', 'c1_003.nii', 'c1_004.nii', 'c1_005.nii']
# Columns in DataFrame: ['label', 'image_name', 'mask_name', 'Age (years)', 'Gender', 'Pathological T stage', 'Pathological grade', "Type of patient's tumor number"]
# Training set: 219 samples
# Validation set: 55 samples
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_011.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_011.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_011_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_011.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_13.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_13.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_13_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_13.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_032.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_032.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_032_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_032.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_036.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_036.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_036_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_036.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_101.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_101.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_101_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_101.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_017.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_017.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_017_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_017.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_23.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_23.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_23_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_23.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_056.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_056.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_056_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_056.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_078.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_078.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_078_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_078.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_33.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_33.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_33_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_33.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_26.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_26.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_26_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_26.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_066.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_066.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_066_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_066.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_019.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_019.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_019_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_019.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_28.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_28.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_28_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_28.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_40.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_40.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_40_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_40.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_071.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_071.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_071_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_071.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_085.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_085.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_085_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_085.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_048.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_048.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_048_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_048.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_083.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_083.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_083_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_083.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_04.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_04.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_04_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_04.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_037.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_037.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_037_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_037.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_118.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_118.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_118_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_118.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_050.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_050.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_050_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_050.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_09.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_09.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_09_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_09.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_06.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_06.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_06_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_06.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_030.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_030.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_030_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_030.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_067.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_067.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_067_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_067.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_25.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_25.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_25_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_25.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_23.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_23.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_23_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_23.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_20.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_20.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_20_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_20.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_24.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_24.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_24_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_24.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_15.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_15.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_15_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_15.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_42.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_42.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_42_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_42.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_119.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_119.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_119_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_119.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_058.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_058.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_058_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_058.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_003.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_003.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_003_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_003.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_065.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_065.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_065_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_065.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_082.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_082.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_082_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_082.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_106.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_106.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_106_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_106.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_108.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_108.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_108_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_108.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_17.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_17.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_17_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_17.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_063.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_063.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_063_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_063.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_11.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_11.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_11_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_11.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_028.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_028.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_028_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_028.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_37.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_37.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_37_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_37.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_24.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_24.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_24_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_24.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_092.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_092.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_092_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_092.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_006.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_006.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_006_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_006.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_089.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_089.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_089_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_089.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_049.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_049.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_049_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_049.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_114.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_114.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_114_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_114.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_19.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_19.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_19_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_19.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_103.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_103.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_103_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_103.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_36.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_36.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_36_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_36.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_074.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_074.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_074_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_074.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_16.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_16.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_16_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_16.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_013.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_013.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_013_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_013.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_034.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_034.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_034_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_034.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_027.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_027.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_027_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_027.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_46.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_46.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_46_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_46.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_044.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_044.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_044_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_044.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_08.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_08.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_08_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_08.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_23.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_23.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_23_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_23.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_039.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_039.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_039_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_039.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_13.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_13.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_13_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_13.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_20.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_20.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_20_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_20.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_025.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_025.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_025_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_025.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_24.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_24.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_24_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_24.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_105.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_02.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_02.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_02_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_02.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_001.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_001.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_001_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_001.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_077.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_077.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_077_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_077.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_05.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_05.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_05_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_05.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_06.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_06.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_06_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_06.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_035.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_035.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_035_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_035.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_110.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_110.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_110_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_110.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_32.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_32.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_32_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_32.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_06.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_06.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_06_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_06.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_012.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_012.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_012_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_012.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_29.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_29.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_29_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_29.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_19.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_19.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_19_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_19.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_026.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_026.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_026_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_026.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_22.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_22.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_22_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_22.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_005.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_005.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_005_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_005.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_031.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_031.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_031_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_031.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_08.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_08.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_08_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_08.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_03.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_03.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_03_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_03.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_13.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_03.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_03.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_03_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_03.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_102.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_102.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_102_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_102.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_053.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_095.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_095.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_095_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_095.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_21.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_21.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_21_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_21.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_14.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_14.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_14_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_14.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_059.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_059.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_059_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_059.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_15.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_15.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_15_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_15.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_116.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_116.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_116_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_116.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_093.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_113.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_113.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_113_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_113.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_023.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_023.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_023_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_023.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_12.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_08.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_070.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_070.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_070_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_070.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_038.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_35.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_35.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_35_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_35.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_05.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_05.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_05_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_05.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_15.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_15.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_15_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_15.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_02.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_02.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_02_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_02.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_02.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_02.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_02_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_02.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_041.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_041.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_041_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_041.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_107.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_30.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_30.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_30_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_30.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_43.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_43.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_43_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_43.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_004.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_004.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_004_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_004.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_080.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_080.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_080_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_080.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_046.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_046.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_046_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_046.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_100.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_002.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_002.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_002_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_002.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_11.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_11.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_11_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_11.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_079.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_04.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_04.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_04_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_04.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_069.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_069.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_069_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_069.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_45.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_45.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_45_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_45.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_033.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_033.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_033_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_033.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_03.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_03.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_03_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_03.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_008.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_008.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_008_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_008.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_12.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_12.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_12_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_12.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_38.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_38.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_38_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_38.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_07.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_084.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_084.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_084_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_084.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_076.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_072.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_072.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_072_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_072.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_096.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_096.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_096_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_096.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_045.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_045.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_045_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_045.nii due to invalid slices
# ...
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_05.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_34.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_34.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_34_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_34.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_22.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_22.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_22_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_22.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_18.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_18.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_18_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_18.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_16.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_16.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_16_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_16.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_41.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_41.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_41_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_41.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_12.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_12.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_12_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_12.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_09.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_068.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_068.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_068_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_068.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_109.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_109.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_109_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_109.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_20.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_20.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_20_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_20.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_115.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_115.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_115_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_115.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_104.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_104.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_104_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_104.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_39.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_39.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_39_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_39.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_052.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_052.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_052_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_052.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_073.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_073.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_073_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_073.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_22.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_062.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_062.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_062_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_062.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_18.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_18.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_18_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_18.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_17.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_17.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_17_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_17.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_01.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_01.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_01_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_01.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_088.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_088.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_088_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_088.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_040.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_040.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_040_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_040.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_010.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_010.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_010_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_010.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_087.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_022.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_022.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_022_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_022.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_090.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_090.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_090_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_090.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_091.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_091.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_091_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_091.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_064.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_064.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_064_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_064.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_16.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c3_17.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_007.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_007.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_007_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_007.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_057.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_057.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_057_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_057.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_042.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_094.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_055.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_024.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_086.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_086.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_086_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_086.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_44.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_44.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_44_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_44.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_020.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_020.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_020_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_020.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_26.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_26.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_26_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_26.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_099.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_099.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_099_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_099.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_19.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_19.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_19_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c4_19.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_075.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_075.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_075_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_075.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_112.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_112.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_112_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_112.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_117.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_117.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_117_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_117.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_016.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_016.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_016_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c1_016.nii due to invalid slices
# right HERE /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_21.nii
# Processing /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_21.nii
# Mask not found: /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_21_mask.nii
# Skipped /kaggle/input/all-zendo-dataset/DATA/T2WI/c2_21.nii due to invalid slices
# Found 0 valid image-mask pairs
# Total slices: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/1523116323.py in <cell line: 0>()
#     369
#     370     # NEW: Check dataset sizes before creating loaders
# --> 371     print(f"Train dataset size: {len(train_dataset)} slices")
#     372     print(f"Validation dataset size: {len(val_dataset)} slices")
#     373
#
# /tmp/ipykernel_31/1523116323.py in __len__(self)
#     181         # NEW: Raise error if dataset is empty
#     182         if len(self.image_slices) == 0:
# --> 183             raise ValueError("Dataset is empty. No valid image-mask pairs found.")
#     184         return len(self.image_slices)
#     185
#
# ValueError: Dataset is empty. No valid image-mask pairs found.

# %%
# Main execution
if __name__ == "__main__":
    # Device configuration
    device = torch.device("cuda")
    
    # Split dataset
    train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
    print(train_df)
    # Create datasets and loaders
    train_dataset = SegmentationDataset(train_df, t2wi_dir, augmentation=True)
    val_dataset = SegmentationDataset(val_df, t2wi_dir, augmentation=False)
    
    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)
    
    # Initialize model, loss, and optimizer
    model = UNet(in_channels=3, out_channels=1).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    # Train model
    num_epochs = 20
    train_losses, val_dices = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
    
    # Save model
    torch.save(model.state_dict(), "/kaggle/working/unet_segmentation.pth")
    
    # Visualize predictions
    visualize_predictions(model, val_loader, device)
    
    # Plot training metrics
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label="Training Loss")
    plt.title("Training Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(val_dices, label="Validation Dice")
    plt.title("Validation Dice Score")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Score")
    plt.legend()
    
    plt.tight_layout()
    plt.savefig("/kaggle/working/training_metrics.png")
    plt.show()
# Out:
#      label  image_name        mask_name  Age (years)  Gender  \
# 10       0  c1_011.nii    c1_011.nii.gz           64    Male
# 256      1   c4_13.nii     c4_13.nii.gz           80    Male
# 120      0  c1_093.nii  c1_093_1.nii.gz           73  Female
# 33       0  c1_032.nii    c1_032.nii.gz           80    Male
# 173      0   c2_13.nii   c2_13_2.nii.gz           73    Male
# ..     ...         ...              ...          ...     ...
# 188      0   c2_28.nii     c2_28.nii.gz           63    Male
# 71       1  c1_060.nii    c1_060.nii.gz           74    Male
# 106      0  c1_081.nii    c1_081.nii.gz           71    Male
# 270      1   c4_27.nii     c4_27.nii.gz           82    Male
# 102      0  c1_079.nii  c1_079_1.nii.gz           70    Male
#
#     Pathological T stage Pathological grade Type of patient's tumor number
# 10                    Ta                Low                         Single
# 256                   T2                Low                         Single
# 120                   Ta               High                       Multiple
# 33                    T1               High                         Single
# 173                   Ta               High                       Multiple
# ..                   ...                ...                            ...
# 188                   Ta                Low                         Single
# 71                    T2               High                         Single
# 106                   Ta                Low                         Single
# 270                   T2               High                         Single
# 102                   Ta               High                       Multiple
#
# [219 rows x 8 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/3277944541.py in <cell line: 0>()
#      11     val_dataset = SegmentationDataset(val_df, t2wi_dir, augmentation=False)
#      12
# ---> 13     train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
#      14     val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)
#      15
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     374             else:  # map-style
#     375                 if shuffle:
# --> 376                     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     377                 else:
#     378                     sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/sampler.py in __init__(self, data_source, replacement, num_samples, generator)
#     162
#     163         if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 164             raise ValueError(
#     165                 f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     166             )
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
# Out:
# <__main__.SegmentationDataset object at 0x7cb0d07cb6d0>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/2716549541.py in <cell line: 0>()
#      11     print(train_dataset)
#      12
# ---> 13     train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
#      14     val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=4)
#      15
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     374             else:  # map-style
#     375                 if shuffle:
# --> 376                     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     377                 else:
#     378                     sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/sampler.py in __init__(self, data_source, replacement, num_samples, generator)
#     162
#     163         if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 164             raise ValueError(
#     165                 f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     166             )
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0
